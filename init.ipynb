# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting yfinance
#   Downloading yfinance-0.1.59.tar.gz (25 kB)
# Requirement already satisfied: scikit-learn in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 2)) (0.24.1)
# Collecting pandas_datareader==0.9.0
#   Downloading pandas_datareader-0.9.0-py3-none-any.whl (107 kB)
# Requirement already satisfied: numpy in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 4)) (1.19.5)
# Requirement already satisfied: scipy in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 5)) (1.6.2)
# Requirement already satisfied: matplotlib in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 6)) (3.4.1)
# Requirement already satisfied: ipython in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 7)) (7.22.0)
# Requirement already satisfied: pandas in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 8)) (1.2.4)
# Requirement already satisfied: sympy in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 9)) (1.8)
# Collecting nose
#   Downloading nose-1.3.7-py3-none-any.whl (154 kB)
# Requirement already satisfied: datascience in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 11)) (0.17.0)
# Requirement already satisfied: lxml in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pandas_datareader==0.9.0->-r ./requirements.txt (line 3)) (4.6.3)
# Requirement already satisfied: requests>=2.19.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pandas_datareader==0.9.0->-r ./requirements.txt (line 3)) (2.25.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pandas->-r ./requirements.txt (line 8)) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pandas->-r ./requirements.txt (line 8)) (2021.1)
# Requirement already satisfied: six>=1.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas->-r ./requirements.txt (line 8)) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests>=2.19.0->pandas_datareader==0.9.0->-r ./requirements.txt (line 3)) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests>=2.19.0->pandas_datareader==0.9.0->-r ./requirements.txt (line 3)) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests>=2.19.0->pandas_datareader==0.9.0->-r ./requirements.txt (line 3)) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests>=2.19.0->pandas_datareader==0.9.0->-r ./requirements.txt (line 3)) (3.0.4)
# Requirement already satisfied: pytest in /shared-libs/python3.7/py/lib/python3.7/site-packages (from datascience->-r ./requirements.txt (line 11)) (6.2.3)
# Requirement already satisfied: branca in /shared-libs/python3.7/py/lib/python3.7/site-packages (from datascience->-r ./requirements.txt (line 11)) (0.4.2)
# Requirement already satisfied: bokeh in /shared-libs/python3.7/py/lib/python3.7/site-packages (from datascience->-r ./requirements.txt (line 11)) (2.3.1)
# Requirement already satisfied: sphinx in /shared-libs/python3.7/py/lib/python3.7/site-packages (from datascience->-r ./requirements.txt (line 11)) (3.5.4)
# Requirement already satisfied: setuptools in /root/venv/lib/python3.7/site-packages (from datascience->-r ./requirements.txt (line 11)) (54.1.2)
# Requirement already satisfied: folium>=0.9.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from datascience->-r ./requirements.txt (line 11)) (0.12.1)
# Requirement already satisfied: plotly in /shared-libs/python3.7/py/lib/python3.7/site-packages (from datascience->-r ./requirements.txt (line 11)) (4.14.3)
# Requirement already satisfied: coveralls in /shared-libs/python3.7/py/lib/python3.7/site-packages (from datascience->-r ./requirements.txt (line 11)) (3.0.1)
# Requirement already satisfied: nbsphinx in /shared-libs/python3.7/py/lib/python3.7/site-packages (from datascience->-r ./requirements.txt (line 11)) (0.8.3)
# Requirement already satisfied: coverage in /shared-libs/python3.7/py/lib/python3.7/site-packages (from datascience->-r ./requirements.txt (line 11)) (5.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib->-r ./requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib->-r ./requirements.txt (line 6)) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from matplotlib->-r ./requirements.txt (line 6)) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib->-r ./requirements.txt (line 6)) (8.2.0)
# Requirement already satisfied: jinja2>=2.9 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from folium>=0.9.1->datascience->-r ./requirements.txt (line 11)) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jinja2>=2.9->folium>=0.9.1->datascience->-r ./requirements.txt (line 11)) (1.1.1)
# Requirement already satisfied: pygments in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython->-r ./requirements.txt (line 7)) (2.8.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython->-r ./requirements.txt (line 7)) (3.0.18)
# Requirement already satisfied: traitlets>=4.2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython->-r ./requirements.txt (line 7)) (5.0.5)
# Requirement already satisfied: jedi>=0.16 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython->-r ./requirements.txt (line 7)) (0.17.2)
# Requirement already satisfied: backcall in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython->-r ./requirements.txt (line 7)) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython->-r ./requirements.txt (line 7)) (4.8.0)
# Requirement already satisfied: decorator in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython->-r ./requirements.txt (line 7)) (5.0.6)
# Requirement already satisfied: pickleshare in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython->-r ./requirements.txt (line 7)) (0.7.5)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jedi>=0.16->ipython->-r ./requirements.txt (line 7)) (0.7.1)
# Requirement already satisfied: ptyprocess>=0.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pexpect>4.3->ipython->-r ./requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: wcwidth in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->-r ./requirements.txt (line 7)) (0.2.5)
# Requirement already satisfied: ipython-genutils in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from traitlets>=4.2->ipython->-r ./requirements.txt (line 7)) (0.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from scikit-learn->-r ./requirements.txt (line 2)) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from scikit-learn->-r ./requirements.txt (line 2)) (1.0.1)
# Requirement already satisfied: mpmath>=0.19 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from sympy->-r ./requirements.txt (line 9)) (1.2.1)
# Collecting multitasking>=0.0.7
#   Downloading multitasking-0.0.9.tar.gz (8.1 kB)
# Requirement already satisfied: PyYAML>=3.10 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from bokeh->datascience->-r ./requirements.txt (line 11)) (5.4.1)
# Requirement already satisfied: typing-extensions>=3.7.4 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from bokeh->datascience->-r ./requirements.txt (line 11)) (3.7.4.3)
# Requirement already satisfied: tornado>=5.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from bokeh->datascience->-r ./requirements.txt (line 11)) (6.1)
# Requirement already satisfied: packaging>=16.8 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from bokeh->datascience->-r ./requirements.txt (line 11)) (20.9)
# Requirement already satisfied: docopt>=0.6.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from coveralls->datascience->-r ./requirements.txt (line 11)) (0.6.2)
# Requirement already satisfied: nbformat in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbsphinx->datascience->-r ./requirements.txt (line 11)) (5.1.3)
# Requirement already satisfied: docutils in /shared-libs/python3.7/py/lib/python3.7/site-packages (from nbsphinx->datascience->-r ./requirements.txt (line 11)) (0.16)
# Requirement already satisfied: nbconvert!=5.4 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbsphinx->datascience->-r ./requirements.txt (line 11)) (6.0.7)
# Requirement already satisfied: entrypoints>=0.2.2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert!=5.4->nbsphinx->datascience->-r ./requirements.txt (line 11)) (0.3)
# Requirement already satisfied: testpath in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert!=5.4->nbsphinx->datascience->-r ./requirements.txt (line 11)) (0.4.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert!=5.4->nbsphinx->datascience->-r ./requirements.txt (line 11)) (0.8.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert!=5.4->nbsphinx->datascience->-r ./requirements.txt (line 11)) (0.5.3)
# Requirement already satisfied: defusedxml in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert!=5.4->nbsphinx->datascience->-r ./requirements.txt (line 11)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert!=5.4->nbsphinx->datascience->-r ./requirements.txt (line 11)) (0.1.2)
# Requirement already satisfied: bleach in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert!=5.4->nbsphinx->datascience->-r ./requirements.txt (line 11)) (3.3.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert!=5.4->nbsphinx->datascience->-r ./requirements.txt (line 11)) (1.4.3)
# Requirement already satisfied: jupyter-core in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert!=5.4->nbsphinx->datascience->-r ./requirements.txt (line 11)) (4.7.1)
# Requirement already satisfied: nest-asyncio in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert!=5.4->nbsphinx->datascience->-r ./requirements.txt (line 11)) (1.5.1)
# Requirement already satisfied: async-generator in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert!=5.4->nbsphinx->datascience->-r ./requirements.txt (line 11)) (1.10)
# Requirement already satisfied: jupyter-client>=6.1.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert!=5.4->nbsphinx->datascience->-r ./requirements.txt (line 11)) (6.1.12)
# Requirement already satisfied: pyzmq>=13 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert!=5.4->nbsphinx->datascience->-r ./requirements.txt (line 11)) (22.0.3)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbformat->nbsphinx->datascience->-r ./requirements.txt (line 11)) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->nbsphinx->datascience->-r ./requirements.txt (line 11)) (0.17.3)
# Requirement already satisfied: importlib-metadata in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->nbsphinx->datascience->-r ./requirements.txt (line 11)) (3.10.1)
# Requirement already satisfied: attrs>=17.4.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->nbsphinx->datascience->-r ./requirements.txt (line 11)) (20.3.0)
# Requirement already satisfied: imagesize in /shared-libs/python3.7/py/lib/python3.7/site-packages (from sphinx->datascience->-r ./requirements.txt (line 11)) (1.2.0)
# Requirement already satisfied: sphinxcontrib-applehelp in /shared-libs/python3.7/py/lib/python3.7/site-packages (from sphinx->datascience->-r ./requirements.txt (line 11)) (1.0.2)
# Requirement already satisfied: sphinxcontrib-htmlhelp in /shared-libs/python3.7/py/lib/python3.7/site-packages (from sphinx->datascience->-r ./requirements.txt (line 11)) (1.0.3)
# Requirement already satisfied: babel>=1.3 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from sphinx->datascience->-r ./requirements.txt (line 11)) (2.9.0)
# Requirement already satisfied: snowballstemmer>=1.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from sphinx->datascience->-r ./requirements.txt (line 11)) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath in /shared-libs/python3.7/py/lib/python3.7/site-packages (from sphinx->datascience->-r ./requirements.txt (line 11)) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp in /shared-libs/python3.7/py/lib/python3.7/site-packages (from sphinx->datascience->-r ./requirements.txt (line 11)) (1.0.3)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from sphinx->datascience->-r ./requirements.txt (line 11)) (0.7.12)
# Requirement already satisfied: sphinxcontrib-serializinghtml in /shared-libs/python3.7/py/lib/python3.7/site-packages (from sphinx->datascience->-r ./requirements.txt (line 11)) (1.1.4)
# Requirement already satisfied: sphinxcontrib-devhelp in /shared-libs/python3.7/py/lib/python3.7/site-packages (from sphinx->datascience->-r ./requirements.txt (line 11)) (1.0.2)
# Requirement already satisfied: webencodings in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from bleach->nbconvert!=5.4->nbsphinx->datascience->-r ./requirements.txt (line 11)) (0.5.1)
# Requirement already satisfied: zipp>=0.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from importlib-metadata->jsonschema!=2.5.0,>=2.4->nbformat->nbsphinx->datascience->-r ./requirements.txt (line 11)) (3.4.1)
# Requirement already satisfied: retrying>=1.3.3 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from plotly->datascience->-r ./requirements.txt (line 11)) (1.3.3)
# Requirement already satisfied: iniconfig in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pytest->datascience->-r ./requirements.txt (line 11)) (1.1.1)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pytest->datascience->-r ./requirements.txt (line 11)) (0.13.1)
# Requirement already satisfied: toml in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pytest->datascience->-r ./requirements.txt (line 11)) (0.10.2)
# Requirement already satisfied: py>=1.8.2 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pytest->datascience->-r ./requirements.txt (line 11)) (1.10.0)
# Building wheels for collected packages: yfinance, multitasking
#   Building wheel for yfinance (setup.py): started
#   Building wheel for yfinance (setup.py): finished with status 'done'
#   Created wheel for yfinance: filename=yfinance-0.1.59-py2.py3-none-any.whl size=23442 sha256=87b2005ef19a3d4bbdf6711de5de7c6b489e3fd6136c29af38bdc3229da674ec
#   Stored in directory: /root/.cache/pip/wheels/26/af/8b/fac1b47dffef567f945641cdc9b67bb25fae5725d462a8cf81
#   Building wheel for multitasking (setup.py): started
#   Building wheel for multitasking (setup.py): finished with status 'done'
#   Created wheel for multitasking: filename=multitasking-0.0.9-py3-none-any.whl size=8368 sha256=ec8e97e0f596d2db205c160043ec2b06b135d4162ebc540f0b9314927cd9cf46
#   Stored in directory: /root/.cache/pip/wheels/ae/25/47/4d68431a7ec1b6c4b5233365934b74c1d4e665bf5f968d363a
# Successfully built yfinance multitasking
# Installing collected packages: multitasking, yfinance, pandas-datareader, nose
# Successfully installed multitasking-0.0.9 nose-1.3.7 pandas-datareader-0.9.0 yfinance-0.1.59
# WARNING: You are using pip version 21.0.1; however, version 21.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=f5ced862-5fbe-4aaf-aa19-de0a34eeda69' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
